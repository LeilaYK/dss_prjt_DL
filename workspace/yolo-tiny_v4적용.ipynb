# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# %cd "/content/gdrive/MyDrive/darknet/bin/darknet"
# Out:
# /content/gdrive/MyDrive/darknet/bin/darknet

# %%
# !chmod +x ./darknet

# %%
# !tar -xzvf /content/gdrive/MyDrive/darknet/cudnn/cudnn-10.1-linux-x64-v8.0.5.39.tgz -C /usr/local/
# Out:
# cuda/include/cudnn.h
# cuda/include/cudnn_adv_infer.h
# cuda/include/cudnn_adv_train.h
# cuda/include/cudnn_backend.h
# cuda/include/cudnn_cnn_infer.h
# cuda/include/cudnn_cnn_train.h
# cuda/include/cudnn_ops_infer.h
# cuda/include/cudnn_ops_train.h
# cuda/include/cudnn_version.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.8
# cuda/lib64/libcudnn.so.8.0.5
# cuda/lib64/libcudnn_adv_infer.so
# cuda/lib64/libcudnn_adv_infer.so.8
# cuda/lib64/libcudnn_adv_infer.so.8.0.5
# cuda/lib64/libcudnn_adv_train.so
# cuda/lib64/libcudnn_adv_train.so.8
# cuda/lib64/libcudnn_adv_train.so.8.0.5
# cuda/lib64/libcudnn_cnn_infer.so
# cuda/lib64/libcudnn_cnn_infer.so.8
# cuda/lib64/libcudnn_cnn_infer.so.8.0.5
# cuda/lib64/libcudnn_cnn_train.so
# cuda/lib64/libcudnn_cnn_train.so.8
# cuda/lib64/libcudnn_cnn_train.so.8.0.5
# cuda/lib64/libcudnn_ops_infer.so
# cuda/lib64/libcudnn_ops_infer.so.8
# cuda/lib64/libcudnn_ops_infer.so.8.0.5
# ...

# %%
# %ls
# Out:
# darknet*  git_darknet/  raw_video/  train/   trial3/
# data/     pink/         study/      trial2/

# %%
# !LD_LIBRARY_PATH=/usr/local/cuda/lib64/ ./darknet detector train trial3/dummy.data trial3/yolov4-tiny.cfg -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.917041), count: 12, class_loss = 0.008639, iou_loss = 0.355200, total_loss = 0.363839
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.902901), count: 43, class_loss = 0.015881, iou_loss = 4.778250, total_loss = 4.794131
#  total_bbox = 564656, rewritten_bbox = 0.000000 %
#
#  5446: 0.024750, 0.029727 avg loss, 0.000026 rate, 0.346940 seconds, 348544 images, 0.158219 hours left
# Loaded: 0.528224 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.935575), count: 16, class_loss = 0.001172, iou_loss = 0.490603, total_loss = 0.491775
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.913021), count: 45, class_loss = 0.069138, iou_loss = 4.292919, total_loss = 4.362057
# ...

# %%
# !./darknet detector demo trial3/dummy.data trial3/yolov4-tiny.cfg trial3/backup//yolov4-tiny_last.weights raw_video/05.mp4 -i 0 -out_filename trial3/result/trial_5_v4.avi -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
# ...

# %%
# !./darknet detector demo trial3/dummy.data trial3/yolov4-tiny.cfg trial3/backup//yolov4-tiny_last.weights raw_video/04.mp4 -i 0 -out_filename trial3/result/trial_4_v4.avi -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
# ...

# %%
# !./darknet detector demo trial3/dummy.data trial3/yolov4-tiny.cfg trial3/backup//yolov4-tiny_last.weights raw_video/02.mp4 -i 0 -out_filename trial3/result/trial_2_v4.avi -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:51.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:52.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:54.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:53.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
# person1: 75%
#
# FPS:53.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
# person1: 82%
#
# FPS:54.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
# person1: 34%
#
# FPS:55.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
# person1: 52%
#
# FPS:57.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
# person1: 37%
#
# FPS:58.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:59.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:60.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# dummy: 100%
#
# FPS:61.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# ...
